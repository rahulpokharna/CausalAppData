# %%
import csv, copy

import numpy as np
import matplotlib.pyplot as plt

from scipy.stats import chi2, multivariate_normal

# %%
import pandas as pd

df = pd.read_csv('googleplaystore.csv')
df

# Number of points in the data, used for the ranges/iterating through the data
num_data = 10840

# %%
df.keys()
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
# Convert num installs to integer
def convertInstallToInt(input):
    input = input.replace(",","")
    mil = False
    if(input[-1] == '+'):
        input = input[:-1]
    if(input[-1] == 'M'):
        input = input[:-1]
        mil = True
    
    out = float(input)
    if mil:
        out = out * 1000000
    out = int(out)
    return out

# %%
print(convertInstallToInt("1,000,000+"))
print(convertInstallToInt("1,000+"))
print(convertInstallToInt("50+"))
print(convertInstallToInt("1.3M"))
print(convertInstallToInt("1.6M+"))
# Out:
# 1000000
# 1000
# 50
# 1300000
# 1600000

# %%
df['Installs']
# Out:
# 0            10,000+
# 1           500,000+
# 2         5,000,000+
# 3        50,000,000+
# 4           100,000+
# 5            50,000+
# 6            50,000+
# 7         1,000,000+
# 8         1,000,000+
# 9            10,000+
# 10        1,000,000+
# 11        1,000,000+
# 12       10,000,000+
# 13          100,000+
# 14          100,000+
# 15            5,000+
# 16          500,000+
# 17           10,000+
# 18        5,000,000+
# 19       10,000,000+
# 20          100,000+
# 21          100,000+
# 22          500,000+
# 23          100,000+
# 24           50,000+
# 25           10,000+
# 26          500,000+
# 27          100,000+
# 28           10,000+
# 29          100,000+
#             ...
# 10810           100+
# 10811         1,000+
# 10812        10,000+
# 10813        50,000+
# 10814       500,000+
# 10815           100+
# 10816       100,000+
# 10817        10,000+
# 10818         5,000+
# 10819         1,000+
# 10820            50+
# 10821            10+
# 10822           100+
# 10823        10,000+
# 10824           100+
# 10825     5,000,000+
# 10826         5,000+
# 10827        10,000+
# 10828        10,000+
# 10829       100,000+
# 10830         5,000+
# 10831       100,000+
# 10832         1,000+
# 10833           500+
# 10834            10+
# 10835         5,000+
# 10836           100+
# 10837         1,000+
# 10838         1,000+
# 10839    10,000,000+
# Name: Installs, Length: 10840, dtype: object

# %%
# count = 0
# for i in range(10841):
# #     print(df[i:i+1])
#     count += 1
    
print(df.loc[10472])
# proportion of reviews to installs
install_proportion = []
for i in range(num_data):
#     install_proportion.append(df.loc[i])
    
    # Pure value
#     print(df.loc[i,"Installs"])
    
    # Check the type (should be str)
#     print(type(df.loc[i,"Installs"]))
    
    # Convert from str to int
#     print(i)
    if np.isnan(df.loc[i,"Rating"]):
        proportion = -1
    else:
        num = int(df.loc[i,"Reviews"]) # .replace(",",""))
        denom = int(df.loc[i,"Installs"][:-1].replace(",",""))
        proportion = num / denom
#     print(proportion)
    install_proportion.append([proportion, df.loc[i,"Price"], denom, df.loc[i, "Category"], df.loc[i, "Type"]])
    
    
#     for key, dat in zip(df.keys(), df.loc[i]):
#         print(key)
#         print(dat)
#         print(df.loc[i,"Installs"])
#         print()
#     print('-------------------------')
    #     print(type(df[0:1][key]))

install_proportion

# df.loc[0][0]

# for i in df.loc[0]:
#     print(i)
# print(count)
# Out:
# App               osmino Wi-Fi: free WiFi
# Category                            TOOLS
# Rating                                4.2
# Reviews                            134203
# Size                                 4.1M
# Installs                      10,000,000+
# Type                                 Free
# Price                                   0
# Content Rating                   Everyone
# Genres                              Tools
# Last Updated               August 7, 2018
# Current Ver                       6.06.14
# Android Ver                    4.4 and up
# Name: 10472, dtype: object
# [[0.0159, '0', 10000, 'ART_AND_DESIGN', 'Free'],
#  [0.001934, '0', 500000, 'ART_AND_DESIGN', 'Free'],
#  [0.017502, '0', 5000000, 'ART_AND_DESIGN', 'Free'],
#  [0.00431288, '0', 50000000, 'ART_AND_DESIGN', 'Free'],
#  [0.00967, '0', 100000, 'ART_AND_DESIGN', 'Free'],
#  [0.00334, '0', 50000, 'ART_AND_DESIGN', 'Free'],
#  [0.00356, '0', 50000, 'ART_AND_DESIGN', 'Free'],
#  [0.036815, '0', 1000000, 'ART_AND_DESIGN', 'Free'],
#  [0.013791, '0', 1000000, 'ART_AND_DESIGN', 'Free'],
#  [0.0121, '0', 10000, 'ART_AND_DESIGN', 'Free'],
#  [0.01388, '0', 1000000, 'ART_AND_DESIGN', 'Free'],
#  [0.008788, '0', 1000000, 'ART_AND_DESIGN', 'Free'],
#  [0.0044829, '0', 10000000, 'ART_AND_DESIGN', 'Free'],
#  [0.04326, '0', 100000, 'ART_AND_DESIGN', 'Free'],
#  [0.01518, '0', 100000, 'ART_AND_DESIGN', 'Free'],
#  [0.011, '0', 5000, 'ART_AND_DESIGN', 'Free'],
#  [0.007264, '0', 500000, 'ART_AND_DESIGN', 'Free'],
#  [0.0027, '0', 10000, 'ART_AND_DESIGN', 'Free'],
#  [0.0388432, '0', 5000000, 'ART_AND_DESIGN', 'Free'],
#  [0.0224399, '0', 10000000, 'ART_AND_DESIGN', 'Free'],
#  [0.0045, '0', 100000, 'ART_AND_DESIGN', 'Free'],
#  [0.00654, '0', 100000, 'ART_AND_DESIGN', 'Free'],
#  [0.015398, '0', 500000, 'ART_AND_DESIGN', 'Free'],
#  [-1, '0', 500000, 'ART_AND_DESIGN', 'Free'],
#  [0.00236, '0', 50000, 'ART_AND_DESIGN', 'Free'],
#  [0.0192, '0', 10000, 'ART_AND_DESIGN', 'Free'],
#  [0.04052, '0', 500000, 'ART_AND_DESIGN', 'Free'],
#  [0.00203, '0', 100000, 'ART_AND_DESIGN', 'Free'],
#  [0.0136, '0', 10000, 'ART_AND_DESIGN', 'Free'],
#  [0.00223, '0', 100000, 'ART_AND_DESIGN', 'Free'],
#  [0.0112, '0', 100000, 'ART_AND_DESIGN', 'Free'],
#  [0.00454, '0', 50000, 'ART_AND_DESIGN', 'Free'],
#  [0.05035, '0', 100000, 'ART_AND_DESIGN', 'Free'],
#  [0.01015, '0', 100000, 'ART_AND_DESIGN', 'Free'],
#  [0.0353, '0', 10000, 'ART_AND_DESIGN', 'Free'],
#  [0.00564, '0', 100000, 'ART_AND_DESIGN', 'Free'],
#  [0.01629, '0', 500000, 'ART_AND_DESIGN', 'Free'],
#  [0.0073278, '0', 5000000, 'ART_AND_DESIGN', 'Free'],
#  [0.0158, '0', 10000, 'ART_AND_DESIGN', 'Free'],
#  [0.001182, '0', 500000, 'ART_AND_DESIGN', 'Free'],
#  [0.0117, '0', 10000, 'ART_AND_DESIGN', 'Free'],
#  [0.00176, '0', 100000, 'ART_AND_DESIGN', 'Free'],
#  [0.0295221, '0', 10000000, 'ART_AND_DESIGN', 'Free'],
#  [0.02206, '0', 100000, 'ART_AND_DESIGN', 'Free'],
#  [0.0026, '0', 10000, 'ART_AND_DESIGN', 'Free'],
#  [0.0174531, '0', 10000000, 'ART_AND_DESIGN', 'Free'],
#  [0.0107, '0', 100000, 'ART_AND_DESIGN', 'Free'],
#  [0.00085, '0', 100000, 'ART_AND_DESIGN', 'Free'],
#  [0.00845, '0', 100000, 'ART_AND_DESIGN', 'Free'],
#  [0.00367, '0', 100000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.001598, '0', 1000000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.00284, '0', 100000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.017057, '0', 1000000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.00129, '0', 100000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.00542, '0', 100000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.10479, '0', 100000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.0161, '0', 50000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.00129, '0', 100000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.01403, '0', 100000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.03971, '0', 100000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.0534, '0', 10000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.07774, '0', 100000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.038846, '0', 1000000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.02431, '0', 100000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.0609, '0', 100000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.0295, '0', 10000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.0038, '0', 50000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.0080422, '0', 5000000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.00356, '0', 100000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.010506, '0', 5000000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.0233972, '0', 5000000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.002758, '0', 500000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.027192, '0', 10000000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.00736, '0', 100000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.014042, '0', 500000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.00394, '0', 50000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.00737, '0', 100000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.003574, '0', 1000000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.00994, '0', 100000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.197136, '0', 1000000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.00284, '0', 50000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.015168, '0', 1000000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.00431, '0', 500000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.00138, '0', 100000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.005414, '0', 1000000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.021777, '0', 1000000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.00348, '0', 100000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.0025, '0', 100000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.013372, '0', 1000000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.0788, '0', 100000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.03617, '0', 100000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.004806, '0', 1000000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.065786, '0', 1000000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.031433, '0', 1000000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.005097, '0', 1000000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.003508, '0', 500000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.00536, '0', 500000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.01288, '0', 100000, 'AUTO_AND_VEHICLES', 'Free'],
#  [0.0378, '0', 500000, 'BEAUTY', 'Free'],
#  [0.04979, '0', 1000000, 'BEAUTY', 'Free'],
#  [0.0115, '0', 100000, 'BEAUTY', 'Free'],
#  [0.003478, '0', 500000, 'BEAUTY', 'Free'],
#  [0.03209, '0', 1000000, 'BEAUTY', 'Free'],
#  [0.00445, '0', 500000, 'BEAUTY', 'Free'],
#  [0.04369, '0', 100000, 'BEAUTY', 'Free'],
#  [0.008572, '0', 1000000, 'BEAUTY', 'Free'],
#  [0.01928, '0', 50000, 'BEAUTY', 'Free'],
#  [0.04205, '0', 1000000, 'BEAUTY', 'Free'],
#  [0.0104, '0', 10000, 'BEAUTY', 'Free'],
#  [0.017934, '0', 1000000, 'BEAUTY', 'Free'],
#  [0.00601, '0', 100000, 'BEAUTY', 'Free'],
#  [0.0036, '0', 10000, 'BEAUTY', 'Free'],
#  [0.00374, '0', 50000, 'BEAUTY', 'Free'],
#  [-1, '0', 50000, 'BEAUTY', 'Free'],
#  [0.003, '0', 10000, 'BEAUTY', 'Free'],
#  [0.0134, '0', 10000, 'BEAUTY', 'Free'],
#  [0.0074, '0', 10000, 'BEAUTY', 'Free'],
#  [0.0113715, '0', 10000000, 'BEAUTY', 'Free'],
#  [0.00719, '0', 500000, 'BEAUTY', 'Free'],
#  [0.009315, '0', 1000000, 'BEAUTY', 'Free'],
#  [0.0015, '0', 50000, 'BEAUTY', 'Free'],
#  [0.0038, '0', 10000, 'BEAUTY', 'Free'],
#  [0.026834, '0', 1000000, 'BEAUTY', 'Free'],
#  [-1, '0', 1000000, 'BEAUTY', 'Free'],
#  [0.004554, '0', 500000, 'BEAUTY', 'Free'],
#  [0.00456, '0', 500000, 'BEAUTY', 'Free'],
#  [-1, '0', 500000, 'BEAUTY', 'Free'],
#  [0.0184, '0', 10000, 'BEAUTY', 'Free'],
#  [0.0018, '0', 5000, 'BEAUTY', 'Free'],
#  [-1, '0', 5000, 'BEAUTY', 'Free'],
#  [-1, '0', 5000, 'BEAUTY', 'Free'],
#  [0.00364, '0', 100000, 'BEAUTY', 'Free'],
#  [0.0036, '0', 5000, 'BEAUTY', 'Free'],
#  [0.00473, '0', 100000, 'BEAUTY', 'Free'],
#  [-1, '0', 100000, 'BEAUTY', 'Free'],
#  [0.0066, '0', 10000, 'BEAUTY', 'Free'],
#  [0.003871, '0', 1000000, 'BEAUTY', 'Free'],
#  [0.00514, '0', 50000, 'BEAUTY', 'Free'],
#  [0.0062, '0', 10000, 'BEAUTY', 'Free'],
#  [0.02914724, '0', 100000000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.03714, '0', 50000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.04478, '0', 100000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.057755, '0', 10000000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.0081408, '0', 100000000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.0246315, '0', 10000000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.045406, '0', 10000000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.0155446, '0', 10000000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.00418, '0', 100000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.022486, '0', 1000000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.020313, '0', 10000000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.00287, '0', 500000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.116507, '0', 1000000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.001433233, '0', 1000000000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.0180936, '0', 5000000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.0086, '0', 100000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.0363934, '0', 10000000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.001934, '0', 500000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.0087873, '0', 10000000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.017506, '0', 1000000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.001862, '0', 1000000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.004168, '0', 500000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.047303, '0', 1000000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.03816, '0', 500000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [-1, '0', 500000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.0171684, '0', 5000000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.07831, '0', 100000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.018323, '0', 5000000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.00924, '0', 500000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.021336, '0', 1000000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.05375, '0', 500000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.003556, '0', 500000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.002709, '0', 1000000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.0129026, '0', 5000000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.0008342, '0', 10000000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.00527, '0', 100000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.01322, '0', 100000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.0168, '0', 100000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.05478, '0', 50000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.00213, '0', 500000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.0233757, '0', 10000000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [-1, '0', 10000000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.008788, '0', 1000000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.051269, '0', 1000000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.030105, '0', 1000000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.000312, '0', 500000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [-1, '0', 500000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.0341157, '0', 10000000, 'BOOKS_AND_REFERENCE', 'Free'],
#  [0.0016129, '0', 10000000, 'BUSINESS', 'Free'],
#  [0.0134946, '0', 50000000, 'BUSINESS', 'Free'],
#  [0.125473, '0', 10000000, 'BUSINESS', 'Free'],
#  [0.017037, '0', 5000000, 'BUSINESS', 'Free'],
#  [0.032584, '0', 1000000, 'BUSINESS', 'Free'],
#  [0.0043546, '0', 50000000, 'BUSINESS', 'Free'],
#  [0.0141982, '0', 5000000, 'BUSINESS', 'Free'],
#  [0.01002861, '0', 100000000, 'BUSINESS', 'Free'],
#  [0.016589, '0', 1000000, 'BUSINESS', 'Free'],
#  [0.148945, '0', 1000000, 'BUSINESS', 'Free'],
#  [0.008916, '0', 500000, 'BUSINESS', 'Free'],
#  [0.0062272, '0', 10000000, 'BUSINESS', 'Free'],
#  [0.0017882, '0', 5000000, 'BUSINESS', 'Free'],
#  [0.046353, '0', 1000000, 'BUSINESS', 'Free'],
#  [0.02558368, '0', 50000000, 'BUSINESS', 'Free'],
#  [0.0088073, '0', 10000000, 'BUSINESS', 'Free'],
#  [0.067, '0', 1000000, 'BUSINESS', 'Free'],
#  [0.0159872, '0', 10000000, 'BUSINESS', 'Free'],
#  [0.0061694, '0', 5000000, 'BUSINESS', 'Free'],
#  [0.0377682, '0', 5000000, 'BUSINESS', 'Free'],
#  [0.0023244, '0', 5000000, 'BUSINESS', 'Free'],
#  [0.0191824, '0', 5000000, 'BUSINESS', 'Free'],
#  [0.04034, '0', 100000, 'BUSINESS', 'Free'],
#  [0.045964, '0', 1000000, 'BUSINESS', 'Free'],
#  [0.014955, '0', 1000000, 'BUSINESS', 'Free'],
#  [0.006903, '0', 1000000, 'BUSINESS', 'Free'],
#  [0.0031614, '0', 10000000, 'BUSINESS', 'Free'],
#  [0.004611, '0', 5000000, 'BUSINESS', 'Free'],
#  [0.019023, '0', 1000000, 'BUSINESS', 'Free'],
#  [0.0414744, '0', 5000000, 'BUSINESS', 'Free'],
#  [0.01225, '0', 100000, 'BUSINESS', 'Free'],
#  [0.0380837, '0', 10000000, 'BUSINESS', 'Free'],
#  [0.0106, '0', 1000000, 'BUSINESS', 'Free'],
#  [0.074359, '0', 1000000, 'BUSINESS', 'Free'],
#  [0.00822, '0', 100000, 'BUSINESS', 'Free'],
#  [0.016161, '0', 5000000, 'BUSINESS', 'Free'],
#  [0.002287, '0', 1000000, 'BUSINESS', 'Free'],
#  [0.04162, '0', 100000, 'BUSINESS', 'Free'],
#  [0.0002952, '0', 50000000, 'BUSINESS', 'Free'],
#  [0.0046486, '0', 5000000, 'BUSINESS', 'Free'],
#  [-1, '0', 5000000, 'BUSINESS', 'Free'],
#  [0.008978, '0', 1000000, 'BUSINESS', 'Free'],
#  [0.016161, '0', 5000000, 'BUSINESS', 'Free'],
#  [0.042492, '0', 1000000, 'BUSINESS', 'Free'],
#  [0.0286897, '0', 10000000, 'BUSINESS', 'Free'],
#  [0.0103755, '0', 10000000, 'BUSINESS', 'Free'],
#  [0.046505, '0', 1000000, 'BUSINESS', 'Free'],
#  [0.11442, '$4.99', 100000, 'BUSINESS', 'Paid'],
#  [0.10295, '$4.99', 100000, 'BUSINESS', 'Paid'],
#  [0.0159872, '0', 10000000, 'BUSINESS', 'Free'],
#  [0.00592, '0', 50000, 'BUSINESS', 'Free'],
#  [0.0058626, '0', 5000000, 'BUSINESS', 'Free'],
#  [0.0141982, '0', 5000000, 'BUSINESS', 'Free'],
#  [0.0103014, '0', 5000000, 'BUSINESS', 'Free'],
#  [0.01802, '0', 100000, 'BUSINESS', 'Free'],
#  [0.01383, '0', 100000, 'BUSINESS', 'Free'],
#  [0.023175, '0', 1000000, 'BUSINESS', 'Free'],
#  [0.011736, '0', 500000, 'BUSINESS', 'Free'],
#  [0.02111, '0', 100000, 'BUSINESS', 'Free'],
#  [0.010896, '0', 500000, 'BUSINESS', 'Free'],
#  [0.008318, '0', 500000, 'BUSINESS', 'Free'],
#  [0.020815, '0', 1000000, 'BUSINESS', 'Free'],
#  [0.078662, '0', 1000000, 'BUSINESS', 'Free'],
#  [0.007149, '0', 1000000, 'BUSINESS', 'Free'],
#  [0.03079, '0', 100000, 'BUSINESS', 'Free'],
#  [0.058, '0', 100000, 'BUSINESS', 'Free'],
#  [0.006989, '0', 1000000, 'BUSINESS', 'Free'],
#  [0.016422, '0', 1000000, 'BUSINESS', 'Free'],
#  [0.0108741, '0', 10000000, 'BUSINESS', 'Free'],
#  [0.0031614, '0', 10000000, 'BUSINESS', 'Free'],
#  [0.00624, '0', 100000, 'BUSINESS', 'Free'],
#  [0.01661, '0', 100000, 'BUSINESS', 'Free'],
#  [0.0195404, '0', 5000000, 'BUSINESS', 'Free'],
#  [0.00616, '0', 50000, 'BUSINESS', 'Free'],
#  [0.006989, '0', 1000000, 'BUSINESS', 'Free'],
#  [0.005211, '0', 1000000, 'BUSINESS', 'Free'],
#  [0.002116, '0', 500000, 'BUSINESS', 'Free'],
#  [0.0078172, '0', 10000000, 'BUSINESS', 'Free'],
#  [0.0159872, '0', 10000000, 'BUSINESS', 'Free'],
#  [0.00592, '0', 50000, 'BUSINESS', 'Free'],
#  [0.0058626, '0', 5000000, 'BUSINESS', 'Free'],
#  [0.0141982, '0', 5000000, 'BUSINESS', 'Free'],
#  [0.0103014, '0', 5000000, 'BUSINESS', 'Free'],
#  [0.01802, '0', 100000, 'BUSINESS', 'Free'],
#  [0.01383, '0', 100000, 'BUSINESS', 'Free'],
#  [0.023175, '0', 1000000, 'BUSINESS', 'Free'],
#  [0.011736, '0', 500000, 'BUSINESS', 'Free'],
#  [0.02111, '0', 100000, 'BUSINESS', 'Free'],
#  [0.010896, '0', 500000, 'BUSINESS', 'Free'],
#  [0.008318, '0', 500000, 'BUSINESS', 'Free'],
#  [0.020815, '0', 1000000, 'BUSINESS', 'Free'],
#  [0.078662, '0', 1000000, 'BUSINESS', 'Free'],
#  [0.007149, '0', 1000000, 'BUSINESS', 'Free'],
#  [0.03079, '0', 100000, 'BUSINESS', 'Free'],
#  [0.058, '0', 100000, 'BUSINESS', 'Free'],
#  [0.006989, '0', 1000000, 'BUSINESS', 'Free'],
#  [0.016422, '0', 1000000, 'BUSINESS', 'Free'],
#  [0.008978, '0', 1000000, 'BUSINESS', 'Free'],
#  [0.0161608, '0', 5000000, 'BUSINESS', 'Free'],
#  [0.042492, '0', 1000000, 'BUSINESS', 'Free'],
#  [0.0286897, '0', 10000000, 'BUSINESS', 'Free'],
#  [0.0103755, '0', 10000000, 'BUSINESS', 'Free'],
#  [0.046505, '0', 1000000, 'BUSINESS', 'Free'],
#  [0.11442, '$4.99', 100000, 'BUSINESS', 'Paid'],
#  [0.10295, '$4.99', 100000, 'BUSINESS', 'Paid'],
#  [0.0043546, '0', 50000000, 'BUSINESS', 'Free'],
#  [0.01002859, '0', 100000000, 'BUSINESS', 'Free'],
#  [0.010302, '0', 5000000, 'BUSINESS', 'Free'],
#  [0.0413, '0', 10000, 'BUSINESS', 'Free'],
#  [0.023175, '0', 1000000, 'BUSINESS', 'Free'],
#  [0.1013635, '0', 10000000, 'COMICS', 'Free'],
#  [0.04801, '0', 500000, 'COMICS', 'Free'],
#  [0.057106, '0', 1000000, 'COMICS', 'Free'],
#  [0.004498, '0', 500000, 'COMICS', 'Free'],
#  [0.01032, '0', 50000, 'COMICS', 'Free'],
#  [0.01668, '0', 50000, 'COMICS', 'Free'],
#  [0.0202, '0', 50000, 'COMICS', 'Free'],
#  [0.23897, '0', 1000000, 'COMICS', 'Free'],
#  [0.0302, '0', 10000, 'COMICS', 'Free'],
#  [0.0438, '0', 10000, 'COMICS', 'Free'],
#  [0.0073, '0', 10000, 'COMICS', 'Free'],
#  [0.0039, '0', 10000, 'COMICS', 'Free'],
#  [0.0144, '0', 10000, 'COMICS', 'Free'],
#  [0.02181, '0', 100000, 'COMICS', 'Free'],
#  [0.018793, '0', 5000000, 'COMICS', 'Free'],
#  [0.01446, '0', 100000, 'COMICS', 'Free'],
#  [0.012088, '0', 1000000, 'COMICS', 'Free'],
#  [0.00314, '0', 100000, 'COMICS', 'Free'],
#  [0.025671, '0', 1000000, 'COMICS', 'Free'],
#  [0.015194, '0', 1000000, 'COMICS', 'Free'],
#  [0.022551, '0', 1000000, 'COMICS', 'Free'],
#  [0.029839, '0', 1000000, 'COMICS', 'Free'],
#  [0.00279, '0', 100000, 'COMICS', 'Free'],
#  [0.1128774, '0', 5000000, 'COMICS', 'Free'],
#  [-1, '0', 5000000, 'COMICS', 'Free'],
#  [0.01677, '0', 100000, 'COMICS', 'Free'],
#  [0.0757, '0', 10000, 'COMICS', 'Free'],
#  [0.0115, '0', 10000, 'COMICS', 'Free'],
#  [0.025, '0', 5000, 'COMICS', 'Free'],
#  [0.019904, '0', 500000, 'COMICS', 'Free'],
#  [0.018814, '0', 1000000, 'COMICS', 'Free'],
#  [0.0042, '0', 5000, 'COMICS', 'Free'],
#  [0.015, '0', 1000, 'COMICS', 'Free'],
#  [0.0103962, '0', 5000000, 'COMICS', 'Free'],
#  [0.3596, '0', 10000, 'COMICS', 'Free'],
#  [0.02012, '0', 50000, 'COMICS', 'Free'],
#  [0.005968, '0', 1000000, 'COMICS', 'Free'],
#  [0.04895, '0', 100000, 'COMICS', 'Free'],
#  [0.056642847, '0', 1000000000, 'COMMUNICATION', 'Free'],
#  [0.069119316, '0', 1000000000, 'COMMUNICATION', 'Free'],
#  [0.0125257, '0', 10000000, 'COMMUNICATION', 'Free'],
#  [0.009642995, '0', 1000000000, 'COMMUNICATION', 'Free'],
#  [0.01429035, '0', 100000000, 'COMMUNICATION', 'Free'],
#  [0.004604324, '0', 1000000000, 'COMMUNICATION', 'Free'],
#  [0.003419249, '0', 1000000000, 'COMMUNICATION', 'Free'],
#  [0.022669598, '0', 500000000, 'COMMUNICATION', 'Free'],
#  [0.0317358, '0', 5000000, 'COMMUNICATION', 'Free'],
#  [0.03075028, '0', 100000000, 'COMMUNICATION', 'Free'],
#  [0.04187998, '0', 100000000, 'COMMUNICATION', 'Free'],
#  [0.00659395, '0', 100000000, 'COMMUNICATION', 'Free'],
#  [0.009571784, '0', 500000000, 'COMMUNICATION', 'Free'],
#  [0.00133204, '0', 50000000, 'COMMUNICATION', 'Free'],
#  [0.0060418, '0', 5000000, 'COMMUNICATION', 'Free'],
#  [0.0073802, '0', 5000000, 'COMMUNICATION', 'Free'],
#  [0.05149854, '0', 100000000, 'COMMUNICATION', 'Free'],
#  [0.0192948, '0', 10000000, 'COMMUNICATION', 'Free'],
#  [0.0099559, '0', 10000000, 'COMMUNICATION', 'Free'],
#  [0.0437674, '0', 10000000, 'COMMUNICATION', 'Free'],
#  [0.0013698, '0', 10000000, 'COMMUNICATION', 'Free'],
#  [0.02473509, '0', 100000000, 'COMMUNICATION', 'Free'],
#  [0.020769, '0', 1000000, 'COMMUNICATION', 'Free'],
#  [0.03688, '0', 1000000, 'COMMUNICATION', 'Free'],
#  [0.0171031, '0', 10000000, 'COMMUNICATION', 'Free'],
#  [0.0127086, '0', 5000000, 'COMMUNICATION', 'Free'],
#  [0.0045487, '0', 10000000, 'COMMUNICATION', 'Free'],
#  [0.0615381, '0', 10000000, 'COMMUNICATION', 'Free'],
#  [0.02451083, '0', 100000000, 'COMMUNICATION', 'Free'],
#  [0.0066106, '0', 5000000, 'COMMUNICATION', 'Free'],
#  [0.05387333, '0', 100000000, 'COMMUNICATION', 'Free'],
#  [0.0364812, '0', 100000000, 'COMMUNICATION', 'Free'],
#  [0.0136662, '0', 10000000, 'COMMUNICATION', 'Free'],
#  [0.04237, '0', 1000000, 'COMMUNICATION', 'Free'],
#  [0.0078181, '0', 100000000, 'COMMUNICATION', 'Free'],
#  [0.0312825, '0', 100000000, 'COMMUNICATION', 'Free'],
#  [0.004166474, '0', 500000000, 'COMMUNICATION', 'Free'],
#  [0.0541389, '0', 10000000, 'COMMUNICATION', 'Free'],
#  [0.046702, '0', 1000000, 'COMMUNICATION', 'Free'],
#  [0.02939, '0', 100000, 'COMMUNICATION', 'Free'],
#  [0.0013761, '0', 10000000, 'COMMUNICATION', 'Free'],
#  [0.0258556, '0', 10000000, 'COMMUNICATION', 'Free'],
#  [0.0040751, '0', 10000000, 'COMMUNICATION', 'Free'],
#  [0.035425844, '0', 500000000, 'COMMUNICATION', 'Free'],
#  [0.0050042, '0', 5000000, 'COMMUNICATION', 'Free'],
#  [0.0054374, '0', 5000000, 'COMMUNICATION', 'Free'],
#  [0.069119316, '0', 1000000000, 'COMMUNICATION', 'Free'],
#  [0.056646578, '0', 1000000000, 'COMMUNICATION', 'Free'],
#  [0.009571976, '0', 500000000, 'COMMUNICATION', 'Free'],
#  [0.0122498, '0', 10000000, 'COMMUNICATION', 'Free'],
#  [0.022669946, '0', 500000000, 'COMMUNICATION', 'Free'],
#  [0.003419433, '0', 1000000000, 'COMMUNICATION', 'Free'],
#  [0.0132014, '0', 10000000, 'COMMUNICATION', 'Free'],
#  [0.0166478, '0', 5000000, 'COMMUNICATION', 'Free'],
#  [0.01189456, '0', 50000000, 'COMMUNICATION', 'Free'],
#  [0.05387446, '0', 100000000, 'COMMUNICATION', 'Free'],
#  [0.010484169, '0', 1000000000, 'COMMUNICATION', 'Free'],
#  [0.03128509, '0', 100000000, 'COMMUNICATION', 'Free'],
#  [0.02451093, '0', 100000000, 'COMMUNICATION', 'Free'],
#  [0.0171031, '0', 10000000, 'COMMUNICATION', 'Free'],
#  [0.028765, '0', 100000000, 'COMMUNICATION', 'Free'],
#  [0.0078181, '0', 100000000, 'COMMUNICATION', 'Free'],
#  [0.028238, '0', 1000000, 'COMMUNICATION', 'Free'],
#  [0.0335646, '0', 10000000, 'COMMUNICATION', 'Free'],
#  [0.0350154, '0', 10000000, 'COMMUNICATION', 'Free'],
#  [0.0349384, '0', 10000000, 'COMMUNICATION', 'Free'],
#  [0.0346982, '0', 10000000, 'COMMUNICATION', 'Free'],
#  [0.0244863, '0', 10000000, 'COMMUNICATION', 'Free'],
#  [0.021580578, '0', 500000000, 'COMMUNICATION', 'Free'],
#  [0.0330761, '0', 10000000, 'COMMUNICATION', 'Free'],
#  [0.03732, '0', 1000000, 'COMMUNICATION', 'Free'],
#  [0.1284286, '0', 100000000, 'COMMUNICATION', 'Free'],
#  [0.02546527, '0', 100000000, 'COMMUNICATION', 'Free'],
#  [0.036893, '0', 1000000, 'COMMUNICATION', 'Free'],
#  [0.01588, '0', 1000000, 'COMMUNICATION', 'Free'],
#  [0.034698, '0', 10000000, 'COMMUNICATION', 'Free'],
#  [0.009643041, '0', 1000000000, 'COMMUNICATION', 'Free'],
#  [0.03075118, '0', 100000000, 'COMMUNICATION', 'Free'],
#  [0.04529832, '0', 50000000, 'COMMUNICATION', 'Free'],
#  [0.0541389, '0', 10000000, 'COMMUNICATION', 'Free'],
#  [0.02473693, '0', 100000000, 'COMMUNICATION', 'Free'],
#  [0.042925, '0', 1000000, 'COMMUNICATION', 'Free'],
#  [0.05150471, '0', 100000000, 'COMMUNICATION', 'Free'],
#  [0.0502226, '0', 50000000, 'COMMUNICATION', 'Free'],
#  [0.0364848, '0', 100000000, 'COMMUNICATION', 'Free'],
#  [0.0354297, '0', 500000000, 'COMMUNICATION', 'Free'],
#  [0.0131, '0', 1000000, 'COMMUNICATION', 'Free'],
#  [0.027156, '0', 1000000, 'COMMUNICATION', 'Free'],
#  [0.055098, '0', 1000000, 'COMMUNICATION', 'Free'],
#  [0.1133501, '0', 10000000, 'COMMUNICATION', 'Free'],
#  [0.025156, '0', 500000, 'COMMUNICATION', 'Free'],
#  [0.02193, '0', 500000, 'COMMUNICATION', 'Free'],
#  [0.18247, '$3.99', 100000, 'COMMUNICATION', 'Paid'],
#  [0.0190613, '0', 10000000, 'COMMUNICATION', 'Free'],
#  [0.0125232, '0', 10000000, 'COMMUNICATION', 'Free'],
#  [0.0166478, '0', 5000000, 'COMMUNICATION', 'Free'],
#  [0.022669946, '0', 500000000, 'COMMUNICATION', 'Free'],
#  [0.072065, '0', 1000000, 'COMMUNICATION', 'Free'],
#  [0.02754, '0', 1000000, 'COMMUNICATION', 'Free'],
#  [0.020998, '0', 5000000, 'COMMUNICATION', 'Free'],
#  [0.0177703, '0', 10000000, 'COMMUNICATION', 'Free'],
#  [0.017529, '0', 1000000, 'COMMUNICATION', 'Free'],
#  [0.0177263, '0', 10000000, 'COMMUNICATION', 'Free'],
#  [0.237468, '0', 1000000, 'COMMUNICATION', 'Free'],
#  [0.032254, '0', 1000000, 'COMMUNICATION', 'Free'],
#  [0.0483565, '0', 10000000, 'COMMUNICATION', 'Free'],
#  [0.0552441, '0', 10000000, 'COMMUNICATION', 'Free'],
#  [0.0120616, '0', 5000000, 'COMMUNICATION', 'Free'],
#  [0.0457283, '0', 10000000, 'COMMUNICATION', 'Free'],
#  [0.018765, '0', 5000000, 'COMMUNICATION', 'Free'],
#  [0.032283, '0', 1000000, 'COMMUNICATION', 'Free'],
#  [0.015287, '0', 1000000, 'COMMUNICATION', 'Free'],
#  [0.0411478, '0', 5000000, 'COMMUNICATION', 'Free'],
#  [0.014873, '0', 1000000, 'COMMUNICATION', 'Free'],
#  [0.07820209, '0', 100000000, 'COMMUNICATION', 'Free'],
#  [0.009498, '0', 1000000, 'COMMUNICATION', 'Free'],
#  [0.004604483, '0', 1000000000, 'COMMUNICATION', 'Free'],
#  [0.04188142, '0', 100000000, 'COMMUNICATION', 'Free'],
#  [0.0176854, '0', 5000000, 'COMMUNICATION', 'Free'],
#  [0.0305218, '0', 10000000, 'COMMUNICATION', 'Free'],
#  [0.183374, '0', 1000000, 'COMMUNICATION', 'Free'],
#  [0.020901, '0', 1000000, 'COMMUNICATION', 'Free'],
#  [0.122595, '0', 1000000, 'COMMUNICATION', 'Free'],
#  [0.0124346, '0', 10000000, 'COMMUNICATION', 'Free'],
#  [0.01675684, '0', 50000000, 'COMMUNICATION', 'Free'],
#  [0.0255, '0', 10000, 'COMMUNICATION', 'Free'],
#  [0.008284, '0', 5000000, 'COMMUNICATION', 'Free'],
#  [0.044706, '0', 1000000, 'COMMUNICATION', 'Free'],
#  [0.047414, '0', 500000, 'COMMUNICATION', 'Free'],
#  [0.003419513, '0', 1000000000, 'COMMUNICATION', 'Free'],
#  [0.009571976, '0', 500000000, 'COMMUNICATION', 'Free'],
#  [0.01189456, '0', 50000000, 'COMMUNICATION', 'Free'],
#  [0.02267051, '0', 500000000, 'COMMUNICATION', 'Free'],
#  [0.010484169, '0', 1000000000, 'COMMUNICATION', 'Free'],
#  [0.05387446, '0', 100000000, 'COMMUNICATION', 'Free'],
#  [0.029208, '0', 1000000, 'COMMUNICATION', 'Free'],
#  [0.0382064, '0', 5000000, 'COMMUNICATION', 'Free'],
#  [0.0350154, '0', 10000000, 'COMMUNICATION', 'Free'],
#  [0.0244863, '0', 10000000, 'COMMUNICATION', 'Free'],
#  [0.021580578, '0', 500000000, 'COMMUNICATION', 'Free'],
#  [0.02546527, '0', 100000000, 'COMMUNICATION', 'Free'],
#  [0.1545, '$3.99', 10000, 'DATING', 'Paid'],
#  [0.057, '$6.99', 1000, 'DATING', 'Paid'],
#  [-1, '$1.49', 1000, 'DATING', 'Paid'],
#  [-1, '$2.99', 1000, 'DATING', 'Paid'],
#  [-1, '$3.99', 1000, 'DATING', 'Paid'],
#  [0.02, '$7.99', 100, 'DATING', 'Paid'],
#  [0.0516801, '0', 10000000, 'DATING', 'Free'],
#  [0.0285726, '0', 10000000, 'DATING', 'Free'],
#  [0.0076646, '0', 10000000, 'DATING', 'Free'],
#  [0.02556, '0', 100000, 'DATING', 'Free'],
#  [0.015558, '0', 500000, 'DATING', 'Free'],
#  [0.0123274, '0', 5000000, 'DATING', 'Free'],
#  [0.012632, '0', 1000000, 'DATING', 'Free'],
#  [0.0313724, '0', 10000000, 'DATING', 'Free'],
#  [0.048845, '0', 1000000, 'DATING', 'Free'],
#  [0.0305708, '0', 10000000, 'DATING', 'Free'],
#  [0.006264, '0', 5000000, 'DATING', 'Free'],
#  [0.034492, '0', 5000000, 'DATING', 'Free'],
#  [0.04195, '0', 100000, 'DATING', 'Free'],
#  [0.023266, '0', 500000, 'DATING', 'Free'],
#  [0.010212, '0', 1000000, 'DATING', 'Free'],
#  [0.037053, '0', 1000000, 'DATING', 'Free'],
#  [0.0667, '0', 10000, 'DATING', 'Free'],
#  [0.013202, '0', 1000000, 'DATING', 'Free'],
#  [0.028671, '0', 1000000, 'DATING', 'Free'],
#  [0.01157, '0', 100000, 'DATING', 'Free'],
#  [0.0212626, '0', 10000000, 'DATING', 'Free'],
#  [0.222888, '0', 1000000, 'DATING', 'Free'],
#  [0.02067, '0', 100000, 'DATING', 'Free'],
#  [0.003286, '0', 500000, 'DATING', 'Free'],
#  [0.021, '0', 5000, 'DATING', 'Free'],
#  [0.006828, '0', 500000, 'DATING', 'Free'],
#  [0.0084388, '0', 5000000, 'DATING', 'Free'],
#  [0.011806, '0', 1000000, 'DATING', 'Free'],
#  [0.01999, '0', 100000, 'DATING', 'Free'],
#  [0.022544, '0', 1000000, 'DATING', 'Free'],
#  [0.097684, '0', 1000000, 'DATING', 'Free'],
#  [0.02519, '0', 100000, 'DATING', 'Free'],
#  [0.01146, '0', 100000, 'DATING', 'Free'],
#  [0.026092, '0', 500000, 'DATING', 'Free'],
#  [0.034536, '0', 500000, 'DATING', 'Free'],
#  [0.017444, '0', 500000, 'DATING', 'Free'],
#  [0.00953, '0', 100000, 'DATING', 'Free'],
#  [0.005186, '0', 500000, 'DATING', 'Free'],
#  [0.010754, '0', 500000, 'DATING', 'Free'],
#  [0.00852, '0', 100000, 'DATING', 'Free'],
#  [0.00424, '0', 50000, 'DATING', 'Free'],
#  [0.001972, '0', 1000000, 'DATING', 'Free'],
#  [0.035206, '0', 1000000, 'DATING', 'Free'],
#  [0.05164, '0', 100000, 'DATING', 'Free'],
#  [0.01939, '0', 100000, 'DATING', 'Free'],
#  [0.00277, '0', 100000, 'DATING', 'Free'],
#  [0.008, '0', 10000, 'DATING', 'Free'],
#  [0.00825, '0', 100000, 'DATING', 'Free'],
#  [0.040035, '0', 1000000, 'DATING', 'Free'],
#  [0.01093, '0', 100000, 'DATING', 'Free'],
#  [0.0135418, '0', 10000000, 'DATING', 'Free'],
#  [0.003202, '0', 500000, 'DATING', 'Free'],
#  [0.02212, '0', 100000, 'DATING', 'Free'],
#  [0.057081, '0', 1000000, 'DATING', 'Free'],
#  [0.00482, '0', 50000, 'DATING', 'Free'],
#  [0.0127972, '0', 5000000, 'DATING', 'Free'],
#  [0.015776, '0', 500000, 'DATING', 'Free'],
#  [0.00535, '0', 100000, 'DATING', 'Free'],
#  [0.05084, '0', 100000, 'DATING', 'Free'],
#  [0.00486, '0', 500000, 'DATING', 'Free'],
#  [0.0285726, '0', 10000000, 'DATING', 'Free'],
#  [0.048845, '0', 1000000, 'DATING', 'Free'],
#  [0.02556, '0', 100000, 'DATING', 'Free'],
#  [0.015558, '0', 500000, 'DATING', 'Free'],
#  [0.00837, '0', 100000, 'DATING', 'Free'],
#  [0.012632, '0', 1000000, 'DATING', 'Free'],
#  [0.0123274, '0', 5000000, 'DATING', 'Free'],
#  [0.010754, '0', 500000, 'DATING', 'Free'],
#  [0.023266, '0', 500000, 'DATING', 'Free'],
#  [0.0313724, '0', 10000000, 'DATING', 'Free'],
#  [0.0738, '0', 10000, 'DATING', 'Free'],
#  [0.0305708, '0', 10000000, 'DATING', 'Free'],
#  [0.00953, '0', 100000, 'DATING', 'Free'],
#  [0.04631, '0', 100000, 'DATING', 'Free'],
#  [0.222888, '0', 1000000, 'DATING', 'Free'],
#  [0.034536, '0', 500000, 'DATING', 'Free'],
#  [0.05164, '0', 100000, 'DATING', 'Free'],
#  [0.004953, '0', 1000000, 'DATING', 'Free'],
#  [0.04195, '0', 100000, 'DATING', 'Free'],
#  [0.028671, '0', 1000000, 'DATING', 'Free'],
#  [0.0212626, '0', 10000000, 'DATING', 'Free'],
#  [0.02878, '0', 50000, 'DATING', 'Free'],
#  [0.00329, '0', 500000, 'DATING', 'Free'],
#  [0.013204, '0', 1000000, 'DATING', 'Free'],
#  [0.00853, '0', 100000, 'DATING', 'Free'],
#  [0.0337, '0', 10000, 'DATING', 'Free'],
#  [0.026098, '0', 500000, 'DATING', 'Free'],
#  [0.051698, '0', 1000000, 'DATING', 'Free'],
#  [0.00923, '0', 100000, 'DATING', 'Free'],
#  [0.1546, '$3.99', 10000, 'DATING', 'Paid'],
#  [0.0149, '0', 10000, 'DATING', 'Free'],
#  [0.0198, '0', 10000, 'DATING', 'Free'],
#  [0.013542, '0', 10000000, 'DATING', 'Free'],
#  [0.022545, '0', 1000000, 'DATING', 'Free'],
#  [0.017446, '0', 500000, 'DATING', 'Free'],
#  [0.04634, '0', 500000, 'DATING', 'Free'],
#  [0.02778, '0', 500000, 'DATING', 'Free'],
#  [0.057083, '0', 1000000, 'DATING', 'Free'],
#  [0.00537, '0', 100000, 'DATING', 'Free'],
#  [0.02688, '0', 500000, 'DATING', 'Free'],
#  [0.0143, '0', 10000, 'DATING', 'Free'],
#  [0.01059, '0', 100000, 'DATING', 'Free'],
#  [0.00894, '0', 100000, 'DATING', 'Free'],
#  [0.012382, '0', 500000, 'DATING', 'Free'],
#  [0.02212, '0', 100000, 'DATING', 'Free'],
#  [0.015081, '0', 1000000, 'DATING', 'Free'],
#  [0.008, '0', 10000, 'DATING', 'Free'],
#  [0.0218, '0', 10000, 'DATING', 'Free'],
#  [0.035205, '0', 1000000, 'DATING', 'Free'],
#  [0.024395, '0', 10000000, 'DATING', 'Free'],
#  [0.0236, '0', 10000, 'DATING', 'Free'],
#  [0.05152, '0', 100000, 'DATING', 'Free'],
#  [0.1576, '0', 10000, 'DATING', 'Free'],
#  [0.006701, '0', 1000000, 'DATING', 'Free'],
#  [0.040039, '0', 1000000, 'DATING', 'Free'],
#  [0.01484, '0', 50000, 'DATING', 'Free'],
#  [0.0187, '0', 10000, 'DATING', 'Free'],
#  [0.005012, '0', 500000, 'DATING', 'Free'],
#  [0.0365972, '0', 5000000, 'DATING', 'Free'],
#  [0.008661, '0', 1000000, 'DATING', 'Free'],
#  [0.008, '0', 1000, 'DATING', 'Free'],
#  [0.0118, '0', 5000, 'DATING', 'Free'],
#  [0.035, '0', 1000, 'DATING', 'Free'],
#  [0.056, '0', 500, 'DATING', 'Free'],
#  [0.025, '0', 5000, 'DATING', 'Free'],
#  [0.0185, '0', 10000, 'DATING', 'Free'],
#  [0.06, '0', 100, 'DATING', 'Free'],
#  [0.011, '0', 10000, 'DATING', 'Free'],
#  [-1, '0', 10000, 'DATING', 'Free'],
#  [0.03, '0', 100, 'DATING', 'Free'],
#  [0.005, '0', 1000, 'DATING', 'Free'],
#  [-1, '0', 1000, 'DATING', 'Free'],
#  [0.084, '0', 1000, 'DATING', 'Free'],
#  [0.02, '0', 100, 'DATING', 'Free'],
#  [0.04, '0', 500, 'DATING', 'Free'],
#  [-1, '0', 500, 'DATING', 'Free'],
#  [0.1552, '0', 5000, 'DATING', 'Free'],
#  [0.02, '0', 100, 'DATING', 'Free'],
#  [-1, '0', 100, 'DATING', 'Free'],
#  [-1, '0', 100, 'DATING', 'Free'],
#  [0.0028, '0', 5000, 'DATING', 'Free'],
#  [-1, '0', 5000, 'DATING', 'Free'],
#  [-1, '0', 5000, 'DATING', 'Free'],
#  [0.1, '0', 10, 'DATING', 'Free'],
#  [-1, '0', 10, 'DATING', 'Free'],
#  [-1, '0', 10, 'DATING', 'Free'],
#  [-1, '0', 10, 'DATING', 'Free'],
#  [-1, '0', 10, 'DATING', 'Free'],
#  [-1, '0', 10, 'DATING', 'Free'],
#  [-1, '0', 10, 'DATING', 'Free'],
#  [-1, '0', 10, 'DATING', 'Free'],
#  [0.01, '0', 500, 'DATING', 'Free'],
#  [0.036, '0', 500, 'DATING', 'Free'],
#  [-1, '0', 500, 'DATING', 'Free'],
#  [0.06, '0', 100, 'DATING', 'Free'],
#  [-1, '0', 100, 'DATING', 'Free'],
#  [-1, '0', 100, 'DATING', 'Free'],
#  [-1, '0', 100, 'DATING', 'Free'],
#  [0.05, '0', 100, 'DATING', 'Free'],
#  [-1, '0', 100, 'DATING', 'Free'],
#  [-1, '0', 100, 'DATING', 'Free'],
#  [-1, '0', 100, 'DATING', 'Free'],
#  [-1, '0', 100, 'DATING', 'Free'],
#  [0.002, '0', 500, 'DATING', 'Free'],
#  [0.011, '0', 1000, 'DATING', 'Free'],
#  [-1, '0', 1000, 'DATING', 'Free'],
#  [-1, '0', 1000, 'DATING', 'Free'],
#  [-1, '0', 1000, 'DATING', 'Free'],
#  [-1, '0', 1000, 'DATING', 'Free'],
#  [-1, '0', 1000, 'DATING', 'Free'],
#  [-1, '0', 1000, 'DATING', 'Free'],
#  [-1, '0', 1000, 'DATING', 'Free'],
#  [0.03, '0', 100, 'DATING', 'Free'],
#  [0.0101, '0', 10000, 'DATING', 'Free'],
#  [0.24, '0', 500, 'DATING', 'Free'],
#  [0.024, '0', 1000, 'DATING', 'Free'],
#  [-1, '0', 1000, 'DATING', 'Free'],
#  [-1, '0', 1000, 'DATING', 'Free'],
#  [-1, '0', 1000, 'DATING', 'Free'],
#  [0.06, '0', 100, 'DATING', 'Free'],
#  [0.004954, '0', 1000000, 'DATING', 'Free'],
#  [0.00954, '0', 100000, 'DATING', 'Free'],
#  [0.0256, '0', 100000, 'DATING', 'Free'],
#  [0.0118, '0', 5000, 'DATING', 'Free'],
#  [-1, '0', 5000, 'DATING', 'Free'],
#  [0.010212, '0', 1000000, 'DATING', 'Free'],
#  [0.021, '0', 5000, 'DATING', 'Free'],
#  [-1, '0', 5000, 'DATING', 'Free'],
#  [0.0084394, '0', 5000000, 'DATING', 'Free'],
#  [0.056, '0', 500, 'DATING', 'Free'],
#  [0.06, '0', 100, 'DATING', 'Free'],
#  [0.05168, '0', 100000, 'DATING', 'Free'],
#  [0.012633, '0', 1000000, 'DATING', 'Free'],
#  [0.08321, '0', 500000, 'DATING', 'Free'],
#  [0.008, '0', 1000, 'DATING', 'Free'],
#  [0.0218, '0', 10000, 'DATING', 'Free'],
#  [0.03, '0', 100, 'DATING', 'Free'],
#  [0.004866, '0', 500000, 'DATING', 'Free'],
#  [0.0185, '0', 10000, 'DATING', 'Free'],
#  [0.008, '0', 10000, 'DATING', 'Free'],
#  [0.035, '0', 1000, 'DATING', 'Free'],
#  [-1, '0', 1000, 'DATING', 'Free'],
#  [0.01, '0', 500, 'DATING', 'Free'],
#  [0.025, '0', 5000, 'DATING', 'Free'],
#  [0.0791, '0', 10000, 'DATING', 'Free'],
#  [0.011, '0', 10000, 'DATING', 'Free'],
#  [0.10646, '0', 50000, 'DATING', 'Free'],
#  [0.0478, '0', 10000, 'DATING', 'Free'],
#  [0.00825, '0', 100000, 'DATING', 'Free'],
#  [0.0138, '0', 5000, 'DATING', 'Free'],
#  [0.0158, '0', 10000, 'DATING', 'Free'],
#  [0.024, '0', 1000, 'DATING', 'Free'],
#  [0.0053, '0', 10000, 'DATING', 'Free'],
#  [0.0365972, '0', 5000000, 'DATING', 'Free'],
#  [0.01157, '0', 100000, 'DATING', 'Free'],
#  [0.097699, '0', 1000000, 'DATING', 'Free'],
#  [-1, '0', 1000000, 'DATING', 'Free'],
#  [0.06289924, '0', 100000000, 'EDUCATION', 'Free'],
#  [0.0181893, '0', 10000000, 'EDUCATION', 'Free'],
#  [0.02544, '0', 100000, 'EDUCATION', 'Free'],
#  [0.017075, '0', 5000000, 'EDUCATION', 'Free'],
#  [0.0314299, '0', 10000000, 'EDUCATION', 'Free'],
#  [-1, '0', 10000000, 'EDUCATION', 'Free'],
#  [0.001954, '0', 5000000, 'EDUCATION', 'Free'],
#  [0.032346, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.00815, '0', 500000, 'EDUCATION', 'Free'],
#  [0.021222, '0', 500000, 'EDUCATION', 'Free'],
#  [0.009321, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.056065, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.0028572, '0', 5000000, 'EDUCATION', 'Free'],
#  [0.133136, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.004938, '0', 500000, 'EDUCATION', 'Free'],
#  [0.0072424, '0', 5000000, 'EDUCATION', 'Free'],
#  [0.00078, '0', 500000, 'EDUCATION', 'Free'],
#  [0.00109, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.0266948, '0', 10000000, 'EDUCATION', 'Free'],
#  [0.0342918, '0', 10000000, 'EDUCATION', 'Free'],
#  [0.000748, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.034528, '0', 5000000, 'EDUCATION', 'Free'],
#  [0.00122, '0', 50000, 'EDUCATION', 'Free'],
#  [0.001619, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.003168, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.029855, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.006736, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.007005, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.001778, '0', 500000, 'EDUCATION', 'Free'],
#  [0.005741, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.0055144, '0', 5000000, 'EDUCATION', 'Free'],
#  [0.010852, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.019776, '0', 500000, 'EDUCATION', 'Free'],
#  [0.003858, '0', 500000, 'EDUCATION', 'Free'],
#  [0.01516, '0', 100000, 'EDUCATION', 'Free'],
#  [0.0215301, '0', 10000000, 'EDUCATION', 'Free'],
#  [0.00423, '0', 100000, 'EDUCATION', 'Free'],
#  [0.0509038, '0', 5000000, 'EDUCATION', 'Free'],
#  [0.1107903, '0', 10000000, 'EDUCATION', 'Free'],
#  [0.017075, '0', 5000000, 'EDUCATION', 'Free'],
#  [0.0181893, '0', 10000000, 'EDUCATION', 'Free'],
#  [0.0211856, '0', 10000000, 'EDUCATION', 'Free'],
#  [0.09902, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.0180962, '0', 5000000, 'EDUCATION', 'Free'],
#  [0.032381, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.0497824, '0', 5000000, 'EDUCATION', 'Free'],
#  [0.049711, '0', 5000000, 'EDUCATION', 'Free'],
#  [0.0215301, '0', 10000000, 'EDUCATION', 'Free'],
#  [0.0272145, '0', 10000000, 'EDUCATION', 'Free'],
#  [0.056897, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.008599, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.041185, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.02998, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.0304, '0', 10000, 'EDUCATION', 'Free'],
#  [0.00716, '0', 50000, 'EDUCATION', 'Free'],
#  [0.011904, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.022251, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.022384, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.09902, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.073404, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.012733, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.025183, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.052743, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.061749, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.055704, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.019277, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.13612, '0', 100000, 'EDUCATION', 'Free'],
#  [0.037862, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.18372, '0', 100000, 'EDUCATION', 'Free'],
#  [0.0656, '0', 10000, 'EDUCATION', 'Free'],
#  [0.024, '0', 10000, 'EDUCATION', 'Free'],
#  [0.0055, '0', 50000, 'EDUCATION', 'Free'],
#  [0.027582, '0', 500000, 'EDUCATION', 'Free'],
#  [0.03692, '0', 100000, 'EDUCATION', 'Free'],
#  [0.02363, '0', 100000, 'EDUCATION', 'Free'],
#  [0.01769, '0', 100000, 'EDUCATION', 'Free'],
#  [0.043, '0', 10000, 'EDUCATION', 'Free'],
#  [0.00756, '0', 100000, 'EDUCATION', 'Free'],
#  [0.03963, '0', 100000, 'EDUCATION', 'Free'],
#  [0.00632, '0', 50000, 'EDUCATION', 'Free'],
#  [0.01284, '0', 50000, 'EDUCATION', 'Free'],
#  [0.01058, '0', 100000, 'EDUCATION', 'Free'],
#  [0.02277, '0', 100000, 'EDUCATION', 'Free'],
#  [0.017075, '0', 5000000, 'EDUCATION', 'Free'],
#  [0.0181893, '0', 10000000, 'EDUCATION', 'Free'],
#  [0.06290507, '0', 100000000, 'EDUCATION', 'Free'],
#  [0.0211856, '0', 10000000, 'EDUCATION', 'Free'],
#  [0.0180962, '0', 5000000, 'EDUCATION', 'Free'],
#  [0.09902, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.022384, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.03238, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.034501, '0', 5000000, 'EDUCATION', 'Free'],
#  [0.0069493, '0', 10000000, 'EDUCATION', 'Free'],
#  [0.008599, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.1107884, '0', 10000000, 'EDUCATION', 'Free'],
#  [0.041185, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.007973, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.0266935, '0', 10000000, 'EDUCATION', 'Free'],
#  [0.005695, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.0285264, '0', 5000000, 'EDUCATION', 'Free'],
#  [0.06290507, '0', 100000000, 'EDUCATION', 'Free'],
#  [0.0110512, '0', 5000000, 'EDUCATION', 'Free'],
#  [0.0345016, '0', 5000000, 'EDUCATION', 'Free'],
#  [0.054798, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.00963, '0', 500000, 'EDUCATION', 'Free'],
#  [0.075112, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.033646, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.1107903, '0', 10000000, 'EDUCATION', 'Free'],
#  [0.03143, '0', 10000000, 'EDUCATION', 'Free'],
#  [0.0206527, '0', 10000000, 'EDUCATION', 'Free'],
#  [0.009348, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.007632, '0', 500000, 'EDUCATION', 'Free'],
#  [0.047847, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.016195, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.00412, '0', 50000, 'EDUCATION', 'Free'],
#  [0.028392, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.03241, '0', 100000, 'EDUCATION', 'Free'],
#  [0.00835, '0', 100000, 'EDUCATION', 'Free'],
#  [0.02525, '0', 100000, 'EDUCATION', 'Free'],
#  [0.00828, '0', 100000, 'EDUCATION', 'Free'],
#  [0.0211856, '0', 10000000, 'EDUCATION', 'Free'],
#  [0.0200058, '0', 10000000, 'EDUCATION', 'Free'],
#  [0.01239, '0', 100000, 'EDUCATION', 'Free'],
#  [0.0702, '0', 10000, 'EDUCATION', 'Free'],
#  [0.0108613, '0', 10000000, 'EDUCATION', 'Free'],
#  [0.0069498, '0', 10000000, 'EDUCATION', 'Free'],
#  [0.014855, '0', 10000000, 'EDUCATION', 'Free'],
#  [0.06290507, '0', 100000000, 'EDUCATION', 'Free'],
#  [0.007694, '0', 500000, 'EDUCATION', 'Free'],
#  [0.0110512, '0', 5000000, 'EDUCATION', 'Free'],
#  [0.0168618, '0', 5000000, 'EDUCATION', 'Free'],
#  [0.00963, '0', 500000, 'EDUCATION', 'Free'],
#  [0.0345016, '0', 5000000, 'EDUCATION', 'Free'],
#  [0.1107948, '0', 10000000, 'EDUCATION', 'Free'],
#  [0.0266948, '0', 10000000, 'EDUCATION', 'Free'],
#  [0.028412, '0', 500000, 'EDUCATION', 'Free'],
#  [0.0206532, '0', 10000000, 'EDUCATION', 'Free'],
#  [0.009348, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.0147, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.042828, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.040209, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.037862, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.01405, '0', 100000, 'EDUCATION', 'Free'],
#  [0.0069498, '0', 10000000, 'EDUCATION', 'Free'],
#  [0.0148549, '0', 10000000, 'EDUCATION', 'Free'],
#  [0.0168622, '0', 5000000, 'EDUCATION', 'Free'],
#  [0.0211856, '0', 10000000, 'EDUCATION', 'Free'],
#  [0.0206532, '0', 10000000, 'EDUCATION', 'Free'],
#  [0.0345016, '0', 5000000, 'EDUCATION', 'Free'],
#  [0.256079, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.02078, '0', 100000, 'EDUCATION', 'Free'],
#  [0.016103, '0', 1000000, 'EDUCATION', 'Free'],
#  [0.011, '$3.99', 1000, 'EDUCATION', 'Paid'],
#  [0.021, '$5.99', 1000, 'EDUCATION', 'Paid'],
#  [0.06217, '$3.99', 500000, 'EDUCATION', 'Paid'],
#  [0.03528, '$3.99', 100000, 'EDUCATION', 'Paid'],
#  [0.05456208, '0', 100000000, 'ENTERTAINMENT', 'Free'],
#  [0.011656, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.028948, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.0296771, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.00940178, '0', 50000000, 'ENTERTAINMENT', 'Free'],
#  [0.0010939, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.0197018, '0', 5000000, 'ENTERTAINMENT', 'Free'],
#  [0.0010482, '0', 5000000, 'ENTERTAINMENT', 'Free'],
#  [0.0022508, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.0020582, '0', 5000000, 'ENTERTAINMENT', 'Free'],
#  [0.007165362, '0', 1000000000, 'ENTERTAINMENT', 'Free'],
#  [0.04885646, '0', 100000000, 'ENTERTAINMENT', 'Free'],
#  [0.028396, '0', 5000000, 'ENTERTAINMENT', 'Free'],
#  [0.006979, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.0093236, '0', 5000000, 'ENTERTAINMENT', 'Free'],
#  [0.0206156, '0', 5000000, 'ENTERTAINMENT', 'Free'],
#  [0.017682, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.037, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.0175528, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.01828284, '0', 100000000, 'ENTERTAINMENT', 'Free'],
#  [0.0069846, '0', 5000000, 'ENTERTAINMENT', 'Free'],
#  [0.0684116, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.046916, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.0407698, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.0140595, '0', 50000000, 'ENTERTAINMENT', 'Free'],
#  [0.0064916, '0', 5000000, 'ENTERTAINMENT', 'Free'],
#  [0.0235496, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.011661, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.0653008, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.023063, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.0087384, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.00823366, '0', 50000000, 'ENTERTAINMENT', 'Free'],
#  [0.008918, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.00501498, '0', 100000000, 'ENTERTAINMENT', 'Free'],
#  [0.04266592, '0', 50000000, 'ENTERTAINMENT', 'Free'],
#  [0.02969, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.0261098, '0', 5000000, 'ENTERTAINMENT', 'Free'],
#  [0.01226118, '0', 50000000, 'ENTERTAINMENT', 'Free'],
#  [0.01633682, '0', 100000000, 'ENTERTAINMENT', 'Free'],
#  [0.04205, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.02646, '0', 100000, 'ENTERTAINMENT', 'Free'],
#  [0.021867, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.032732, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.0653008, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.0243747, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.02639, '0', 100000, 'ENTERTAINMENT', 'Free'],
#  [0.01511, '0', 100000, 'ENTERTAINMENT', 'Free'],
#  [0.04455, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.00501497, '0', 100000000, 'ENTERTAINMENT', 'Free'],
#  [0.05456208, '0', 100000000, 'ENTERTAINMENT', 'Free'],
#  [0.015626, '0', 500000, 'ENTERTAINMENT', 'Free'],
#  [0.01033, '0', 100000, 'ENTERTAINMENT', 'Free'],
#  [0.02442, '0', 100000, 'ENTERTAINMENT', 'Free'],
#  [0.015254, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.155234, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.0310066, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.012216, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.0388089, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.0092058, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.0088185, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.00986, '0', 50000, 'ENTERTAINMENT', 'Free'],
#  [0.033387, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.0123279, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.027424, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.0121682, '0', 5000000, 'ENTERTAINMENT', 'Free'],
#  [0.029706, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.05763, '0', 5000000, 'ENTERTAINMENT', 'Free'],
#  [0.014807, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.0319692, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.0061201, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.022998, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.012398, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.035928, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.064448, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.022378, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.00501498, '0', 100000000, 'ENTERTAINMENT', 'Free'],
#  [0.05456599, '0', 100000000, 'ENTERTAINMENT', 'Free'],
#  [0.0296829, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.0310095, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.0088185, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.0388089, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.0092058, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.0123279, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.0319691, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.0121682, '0', 5000000, 'ENTERTAINMENT', 'Free'],
#  [0.05763, '0', 5000000, 'ENTERTAINMENT', 'Free'],
#  [0.032744, '0', 500000, 'ENTERTAINMENT', 'Free'],
#  [0.0116056, '0', 5000000, 'ENTERTAINMENT', 'Free'],
#  [0.033387, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.0061201, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.0736864, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.029706, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.027424, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.003936, '0', 500000, 'ENTERTAINMENT', 'Free'],
#  [0.035279, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.035931, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.014807, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.017247, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.0087723, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.018523, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.0182103, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.0197774, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.008674, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.05456708, '0', 100000000, 'ENTERTAINMENT', 'Free'],
#  [0.0296771, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.0058082, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.0388089, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.0310066, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.0123279, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.0088185, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.0319691, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.015626, '0', 500000, 'ENTERTAINMENT', 'Free'],
#  [0.0121682, '0', 5000000, 'ENTERTAINMENT', 'Free'],
#  [0.0653008, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.027424, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.033387, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.0407719, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.05763, '0', 5000000, 'ENTERTAINMENT', 'Free'],
#  [0.0115033, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.022997, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.0061201, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.00801, '0', 100000, 'ENTERTAINMENT', 'Free'],
#  [0.029706, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.027424, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.012398, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.035279, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.035931, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.022378, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.014807, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.0197774, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.008674, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.008968, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.0303, '0', 10000, 'ENTERTAINMENT', 'Free'],
#  [0.0407719, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.00732, '0', 100000, 'ENTERTAINMENT', 'Free'],
#  [0.01856, '0', 100000, 'ENTERTAINMENT', 'Free'],
#  [0.010145, '0', 5000000, 'ENTERTAINMENT', 'Free'],
#  [0.0123279, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.0243747, '0', 10000000, 'ENTERTAINMENT', 'Free'],
#  [0.01575, '0', 100000, 'ENTERTAINMENT', 'Free'],
#  [0.06238, '$4.99', 100000, 'ENTERTAINMENT', 'Paid'],
#  [0.009941, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.023666, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.067554, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  [0.038769, '0', 1000000, 'ENTERTAINMENT', 'Free'],
#  ...]

# %% [markdown]
# The mean proportion of users who actually review apps:

# %%
np.mean([x[0] for x in install_proportion if x[0] != -1])
# Out:
# 0.03743472632842196

# %% [markdown]
# Broken down across numbers of installs:

# %%
download_counts = {}
for prop in install_proportion:
    if prop[0] != -1:
        if prop[2] not in download_counts.keys():
            download_counts[prop[2]] = [prop[0]]
        else:
            download_counts[prop[2]].append(prop[0])

for count in sorted(download_counts.keys()):
    print(count)
# Out:
# 1
# 5
# 10
# 50
# 100
# 500
# 1000
# 5000
# 10000
# 50000
# 100000
# 500000
# 1000000
# 5000000
# 10000000
# 50000000
# 100000000
# 500000000
# 1000000000

# %% [markdown]
# # IP Weighting

# %%
ip_population = {}

for i in range(num_data):
    if df.loc[i, "Category"] not in ip_population:
        ip_population[df.loc[i, "Category"]] = 1
    else:
        ip_population[df.loc[i, "Category"]] += 1

ip_population = sorted(ip_population.items(), key = 
             lambda kv:(kv[1], kv[0]))

ip_population
# Out:
# [('BEAUTY', 53),
#  ('COMICS', 60),
#  ('PARENTING', 60),
#  ('EVENTS', 64),
#  ('ART_AND_DESIGN', 65),
#  ('WEATHER', 82),
#  ('AUTO_AND_VEHICLES', 85),
#  ('LIBRARIES_AND_DEMO', 85),
#  ('HOUSE_AND_HOME', 88),
#  ('FOOD_AND_DRINK', 127),
#  ('MAPS_AND_NAVIGATION', 137),
#  ('ENTERTAINMENT', 149),
#  ('EDUCATION', 156),
#  ('VIDEO_PLAYERS', 175),
#  ('BOOKS_AND_REFERENCE', 231),
#  ('DATING', 234),
#  ('TRAVEL_AND_LOCAL', 258),
#  ('SHOPPING', 260),
#  ('NEWS_AND_MAGAZINES', 283),
#  ('SOCIAL', 295),
#  ('PHOTOGRAPHY', 335),
#  ('HEALTH_AND_FITNESS', 341),
#  ('FINANCE', 366),
#  ('LIFESTYLE', 382),
#  ('SPORTS', 384),
#  ('COMMUNICATION', 387),
#  ('PERSONALIZATION', 392),
#  ('PRODUCTIVITY', 424),
#  ('BUSINESS', 460),
#  ('MEDICAL', 463),
#  ('TOOLS', 843),
#  ('GAME', 1144),
#  ('FAMILY', 1972)]

# %%
# Get the probabilities from this sample
for pop in ip_population:
    print("Pr[category={}]: ".format(pop[0]), pop[1]/num_data)
# Out:
# Pr[category=BEAUTY]:  0.00488929889298893
# Pr[category=COMICS]:  0.005535055350553505
# Pr[category=PARENTING]:  0.005535055350553505
# Pr[category=EVENTS]:  0.005904059040590406
# Pr[category=ART_AND_DESIGN]:  0.005996309963099631
# Pr[category=WEATHER]:  0.0075645756457564575
# Pr[category=AUTO_AND_VEHICLES]:  0.007841328413284132
# Pr[category=LIBRARIES_AND_DEMO]:  0.007841328413284132
# Pr[category=HOUSE_AND_HOME]:  0.008118081180811807
# Pr[category=FOOD_AND_DRINK]:  0.011715867158671586
# Pr[category=MAPS_AND_NAVIGATION]:  0.012638376383763838
# Pr[category=ENTERTAINMENT]:  0.013745387453874538
# Pr[category=EDUCATION]:  0.014391143911439114
# Pr[category=VIDEO_PLAYERS]:  0.01614391143911439
# Pr[category=BOOKS_AND_REFERENCE]:  0.021309963099630996
# Pr[category=DATING]:  0.02158671586715867
# Pr[category=TRAVEL_AND_LOCAL]:  0.023800738007380074
# Pr[category=SHOPPING]:  0.023985239852398525
# Pr[category=NEWS_AND_MAGAZINES]:  0.0261070110701107
# Pr[category=SOCIAL]:  0.0272140221402214
# Pr[category=PHOTOGRAPHY]:  0.030904059040590407
# Pr[category=HEALTH_AND_FITNESS]:  0.031457564575645754
# Pr[category=FINANCE]:  0.033763837638376384
# Pr[category=LIFESTYLE]:  0.03523985239852399
# Pr[category=SPORTS]:  0.035424354243542434
# Pr[category=COMMUNICATION]:  0.03570110701107011
# Pr[category=PERSONALIZATION]:  0.03616236162361624
# Pr[category=PRODUCTIVITY]:  0.03911439114391144
# Pr[category=BUSINESS]:  0.042435424354243544
# Pr[category=MEDICAL]:  0.042712177121771215
# Pr[category=TOOLS]:  0.07776752767527675
# Pr[category=GAME]:  0.1055350553505535
# Pr[category=FAMILY]:  0.1819188191881919

# %%
# Add the free and paid counts values to each category
for i in range(len(ip_population)):
    free_paid = [0, 0]
    for app in install_proportion:
        if app[3] == ip_population[i][0]:
            if app[4] == 'Free':
                free_paid[0] += 1
            elif app[4] == 'Paid':
                free_paid[1] += 1
    ip_population[i] = ip_population[i] + tuple(free_paid)
    
ip_population
# Out:
# [('BEAUTY', 53, 53, 0),
#  ('COMICS', 60, 60, 0),
#  ('PARENTING', 60, 58, 2),
#  ('EVENTS', 64, 63, 1),
#  ('ART_AND_DESIGN', 65, 62, 3),
#  ('WEATHER', 82, 74, 8),
#  ('AUTO_AND_VEHICLES', 85, 82, 3),
#  ('LIBRARIES_AND_DEMO', 85, 84, 1),
#  ('HOUSE_AND_HOME', 88, 88, 0),
#  ('FOOD_AND_DRINK', 127, 125, 2),
#  ('MAPS_AND_NAVIGATION', 137, 132, 5),
#  ('ENTERTAINMENT', 149, 147, 2),
#  ('EDUCATION', 156, 152, 4),
#  ('VIDEO_PLAYERS', 175, 171, 4),
#  ('BOOKS_AND_REFERENCE', 231, 203, 28),
#  ('DATING', 234, 227, 7),
#  ('TRAVEL_AND_LOCAL', 258, 246, 12),
#  ('SHOPPING', 260, 258, 2),
#  ('NEWS_AND_MAGAZINES', 283, 281, 2),
#  ('SOCIAL', 295, 292, 3),
#  ('PHOTOGRAPHY', 335, 313, 22),
#  ('HEALTH_AND_FITNESS', 341, 325, 16),
#  ('FINANCE', 366, 349, 17),
#  ('LIFESTYLE', 382, 363, 19),
#  ('SPORTS', 384, 360, 24),
#  ('COMMUNICATION', 387, 360, 27),
#  ('PERSONALIZATION', 392, 309, 83),
#  ('PRODUCTIVITY', 424, 396, 28),
#  ('BUSINESS', 460, 446, 14),
#  ('MEDICAL', 463, 354, 109),
#  ('TOOLS', 843, 765, 78),
#  ('GAME', 1144, 1061, 83),
#  ('FAMILY', 1972, 1780, 191)]

# %%
# Get the probabilities that an app is free or paid given its category
for app in ip_population:
    free_prob = app[2]/(app[2] + app[3])
    print("Pr[free | category = {}]: ".format(app[0]), free_prob)
    print("Pr[paid | category = {}]: ".format(app[0]), 1 - free_prob)
    print()
# Out:
# Pr[free | category = BEAUTY]:  1.0
# Pr[paid | category = BEAUTY]:  0.0
#
# Pr[free | category = COMICS]:  1.0
# Pr[paid | category = COMICS]:  0.0
#
# Pr[free | category = PARENTING]:  0.9666666666666667
# Pr[paid | category = PARENTING]:  0.033333333333333326
#
# Pr[free | category = EVENTS]:  0.984375
# Pr[paid | category = EVENTS]:  0.015625
#
# Pr[free | category = ART_AND_DESIGN]:  0.9538461538461539
# Pr[paid | category = ART_AND_DESIGN]:  0.0461538461538461
#
# Pr[free | category = WEATHER]:  0.9024390243902439
# Pr[paid | category = WEATHER]:  0.09756097560975607
#
# Pr[free | category = AUTO_AND_VEHICLES]:  0.9647058823529412
# Pr[paid | category = AUTO_AND_VEHICLES]:  0.03529411764705881
#
# Pr[free | category = LIBRARIES_AND_DEMO]:  0.9882352941176471
# Pr[paid | category = LIBRARIES_AND_DEMO]:  0.0117647058823529
#
# Pr[free | category = HOUSE_AND_HOME]:  1.0
# Pr[paid | category = HOUSE_AND_HOME]:  0.0
#
# Pr[free | category = FOOD_AND_DRINK]:  0.984251968503937
# Pr[paid | category = FOOD_AND_DRINK]:  0.015748031496062964
#
# Pr[free | category = MAPS_AND_NAVIGATION]:  0.9635036496350365
# Pr[paid | category = MAPS_AND_NAVIGATION]:  0.03649635036496346
#
# Pr[free | category = ENTERTAINMENT]:  0.9865771812080537
# Pr[paid | category = ENTERTAINMENT]:  0.01342281879194629
#
# Pr[free | category = EDUCATION]:  0.9743589743589743
# Pr[paid | category = EDUCATION]:  0.02564102564102566
#
# Pr[free | category = VIDEO_PLAYERS]:  0.9771428571428571
# Pr[paid | category = VIDEO_PLAYERS]:  0.02285714285714291
#
# Pr[free | category = BOOKS_AND_REFERENCE]:  0.8787878787878788
# Pr[paid | category = BOOKS_AND_REFERENCE]:  0.12121212121212122
#
# Pr[free | category = DATING]:  0.9700854700854701
# Pr[paid | category = DATING]:  0.02991452991452992
#
# Pr[free | category = TRAVEL_AND_LOCAL]:  0.9534883720930233
# Pr[paid | category = TRAVEL_AND_LOCAL]:  0.046511627906976716
#
# Pr[free | category = SHOPPING]:  0.9923076923076923
# Pr[paid | category = SHOPPING]:  0.007692307692307665
#
# Pr[free | category = NEWS_AND_MAGAZINES]:  0.9929328621908127
# Pr[paid | category = NEWS_AND_MAGAZINES]:  0.007067137809187329
#
# Pr[free | category = SOCIAL]:  0.9898305084745763
# Pr[paid | category = SOCIAL]:  0.01016949152542368
#
# Pr[free | category = PHOTOGRAPHY]:  0.9343283582089552
# Pr[paid | category = PHOTOGRAPHY]:  0.06567164179104479
#
# Pr[free | category = HEALTH_AND_FITNESS]:  0.9530791788856305
# Pr[paid | category = HEALTH_AND_FITNESS]:  0.04692082111436946
#
# Pr[free | category = FINANCE]:  0.953551912568306
# Pr[paid | category = FINANCE]:  0.04644808743169404
#
# Pr[free | category = LIFESTYLE]:  0.9502617801047121
# Pr[paid | category = LIFESTYLE]:  0.04973821989528793
#
# Pr[free | category = SPORTS]:  0.9375
# Pr[paid | category = SPORTS]:  0.0625
#
# Pr[free | category = COMMUNICATION]:  0.9302325581395349
# Pr[paid | category = COMMUNICATION]:  0.06976744186046513
#
# Pr[free | category = PERSONALIZATION]:  0.7882653061224489
# Pr[paid | category = PERSONALIZATION]:  0.21173469387755106
#
# Pr[free | category = PRODUCTIVITY]:  0.9339622641509434
# Pr[paid | category = PRODUCTIVITY]:  0.06603773584905659
#
# Pr[free | category = BUSINESS]:  0.9695652173913043
# Pr[paid | category = BUSINESS]:  0.0304347826086957
#
# Pr[free | category = MEDICAL]:  0.7645788336933045
# Pr[paid | category = MEDICAL]:  0.23542116630669552
#
# Pr[free | category = TOOLS]:  0.9074733096085409
# Pr[paid | category = TOOLS]:  0.09252669039145911
#
# Pr[free | category = GAME]:  0.9274475524475524
# Pr[paid | category = GAME]:  0.07255244755244761
#
# Pr[free | category = FAMILY]:  0.9030948756976154
# Pr[paid | category = FAMILY]:  0.09690512430238463

# %%
# Get the probability that the proportion of reviews is greater than the mean given the category and whether it's free or paid

mean_prop = 0.03743472632842196

for category in ip_population:
    sum_free = 0
    sum_paid = 0
    for app in install_proportion:
        if app[3] == category[0]:
            if app[4] == 'Free' and app[0] > mean_prop:
                sum_free += 1
            if app[4] == 'Paid' and app[0] > mean_prop:
                sum_paid += 1
    print("Pr[prop < mean | free, category = {}]:".format(category[0]), 1-sum_free/category[2], category[2]-sum_free)
    print("Pr[prop > mean | free, category = {}]:".format(category[0]), sum_free/category[2], sum_free)
    print()
    if sum_paid > 0:
        print("Pr[prop < mean | paid, category = {}]:".format(category[0]), 1-sum_paid/category[3], category[3]-sum_paid)
        print("Pr[prop > mean | paid, category = {}]:".format(category[0]), sum_paid/category[3], sum_paid)
        print()
    else:
        print("Pr[prop < mean | paid, category = {}]:".format(category[0]), 1, 0)
        print("Pr[prop > mean | paid, category = {}]:".format(category[0]), 0, 0)
        print()
# Out:
# Pr[prop < mean | free, category = BEAUTY]: 0.8867924528301887 47
# Pr[prop > mean | free, category = BEAUTY]: 0.11320754716981132 6
#
# Pr[prop < mean | paid, category = BEAUTY]: 1 0
# Pr[prop > mean | paid, category = BEAUTY]: 0 0
#
# Pr[prop < mean | free, category = COMICS]: 0.7666666666666666 46
# Pr[prop > mean | free, category = COMICS]: 0.23333333333333334 14
#
# Pr[prop < mean | paid, category = COMICS]: 1 0
# Pr[prop > mean | paid, category = COMICS]: 0 0
#
# Pr[prop < mean | free, category = PARENTING]: 0.896551724137931 52
# Pr[prop > mean | free, category = PARENTING]: 0.10344827586206896 6
#
# Pr[prop < mean | paid, category = PARENTING]: 0.0 0
# Pr[prop > mean | paid, category = PARENTING]: 1.0 2
#
# Pr[prop < mean | free, category = EVENTS]: 0.7936507936507937 50
# Pr[prop > mean | free, category = EVENTS]: 0.20634920634920634 13
#
# Pr[prop < mean | paid, category = EVENTS]: 1 0
# Pr[prop > mean | paid, category = EVENTS]: 0 0
#
# Pr[prop < mean | free, category = ART_AND_DESIGN]: 0.9193548387096774 57
# Pr[prop > mean | free, category = ART_AND_DESIGN]: 0.08064516129032258 5
#
# Pr[prop < mean | paid, category = ART_AND_DESIGN]: 0.0 0
# Pr[prop > mean | paid, category = ART_AND_DESIGN]: 1.0 3
#
# Pr[prop < mean | free, category = WEATHER]: 0.8108108108108107 60
# Pr[prop > mean | free, category = WEATHER]: 0.1891891891891892 14
#
# Pr[prop < mean | paid, category = WEATHER]: 0.375 3
# Pr[prop > mean | paid, category = WEATHER]: 0.625 5
#
# Pr[prop < mean | free, category = AUTO_AND_VEHICLES]: 0.8048780487804879 66
# Pr[prop > mean | free, category = AUTO_AND_VEHICLES]: 0.1951219512195122 16
#
# Pr[prop < mean | paid, category = AUTO_AND_VEHICLES]: 0.6666666666666667 2
# Pr[prop > mean | paid, category = AUTO_AND_VEHICLES]: 0.3333333333333333 1
#
# Pr[prop < mean | free, category = LIBRARIES_AND_DEMO]: 0.9404761904761905 79
# Pr[prop > mean | free, category = LIBRARIES_AND_DEMO]: 0.05952380952380952 5
#
# Pr[prop < mean | paid, category = LIBRARIES_AND_DEMO]: 1 0
# Pr[prop > mean | paid, category = LIBRARIES_AND_DEMO]: 0 0
#
# Pr[prop < mean | free, category = HOUSE_AND_HOME]: 0.8863636363636364 78
# Pr[prop > mean | free, category = HOUSE_AND_HOME]: 0.11363636363636363 10
#
# Pr[prop < mean | paid, category = HOUSE_AND_HOME]: 1 0
# Pr[prop > mean | paid, category = HOUSE_AND_HOME]: 0 0
#
# Pr[prop < mean | free, category = FOOD_AND_DRINK]: 0.808 101
# Pr[prop > mean | free, category = FOOD_AND_DRINK]: 0.192 24
#
# Pr[prop < mean | paid, category = FOOD_AND_DRINK]: 0.5 1
# Pr[prop > mean | paid, category = FOOD_AND_DRINK]: 0.5 1
#
# Pr[prop < mean | free, category = MAPS_AND_NAVIGATION]: 0.8257575757575757 109
# Pr[prop > mean | free, category = MAPS_AND_NAVIGATION]: 0.17424242424242425 23
#
# Pr[prop < mean | paid, category = MAPS_AND_NAVIGATION]: 0.19999999999999996 1
# Pr[prop > mean | paid, category = MAPS_AND_NAVIGATION]: 0.8 4
#
# Pr[prop < mean | free, category = ENTERTAINMENT]: 0.8095238095238095 119
# Pr[prop > mean | free, category = ENTERTAINMENT]: 0.19047619047619047 28
#
# Pr[prop < mean | paid, category = ENTERTAINMENT]: 0.0 0
# Pr[prop > mean | paid, category = ENTERTAINMENT]: 1.0 2
#
# Pr[prop < mean | free, category = EDUCATION]: 0.756578947368421 115
# Pr[prop > mean | free, category = EDUCATION]: 0.24342105263157895 37
#
# Pr[prop < mean | paid, category = EDUCATION]: 0.75 3
# Pr[prop > mean | paid, category = EDUCATION]: 0.25 1
#
# Pr[prop < mean | free, category = VIDEO_PLAYERS]: 0.8362573099415205 143
# Pr[prop > mean | free, category = VIDEO_PLAYERS]: 0.16374269005847952 28
#
# Pr[prop < mean | paid, category = VIDEO_PLAYERS]: 0.0 0
# Pr[prop > mean | paid, category = VIDEO_PLAYERS]: 1.0 4
#
# Pr[prop < mean | free, category = BOOKS_AND_REFERENCE]: 0.7980295566502463 162
# Pr[prop > mean | free, category = BOOKS_AND_REFERENCE]: 0.2019704433497537 41
#
# Pr[prop < mean | paid, category = BOOKS_AND_REFERENCE]: 0.7857142857142857 22
# Pr[prop > mean | paid, category = BOOKS_AND_REFERENCE]: 0.21428571428571427 6
#
# Pr[prop < mean | free, category = DATING]: 0.8193832599118943 186
# Pr[prop > mean | free, category = DATING]: 0.18061674008810572 41
#
# Pr[prop < mean | paid, category = DATING]: 0.5714285714285714 4
# Pr[prop > mean | paid, category = DATING]: 0.42857142857142855 3
#
# Pr[prop < mean | free, category = TRAVEL_AND_LOCAL]: 0.8821138211382114 217
# Pr[prop > mean | free, category = TRAVEL_AND_LOCAL]: 0.11788617886178862 29
#
# Pr[prop < mean | paid, category = TRAVEL_AND_LOCAL]: 0.5 6
# Pr[prop > mean | paid, category = TRAVEL_AND_LOCAL]: 0.5 6
#
# Pr[prop < mean | free, category = SHOPPING]: 0.8333333333333334 215
# Pr[prop > mean | free, category = SHOPPING]: 0.16666666666666666 43
#
# Pr[prop < mean | paid, category = SHOPPING]: 0.0 0
# Pr[prop > mean | paid, category = SHOPPING]: 1.0 2
#
# Pr[prop < mean | free, category = NEWS_AND_MAGAZINES]: 0.8469750889679715 238
# Pr[prop > mean | free, category = NEWS_AND_MAGAZINES]: 0.15302491103202848 43
#
# Pr[prop < mean | paid, category = NEWS_AND_MAGAZINES]: 0.5 1
# Pr[prop > mean | paid, category = NEWS_AND_MAGAZINES]: 0.5 1
#
# Pr[prop < mean | free, category = SOCIAL]: 0.6746575342465753 197
# Pr[prop > mean | free, category = SOCIAL]: 0.3253424657534247 95
#
# Pr[prop < mean | paid, category = SOCIAL]: 0.33333333333333337 1
# Pr[prop > mean | paid, category = SOCIAL]: 0.6666666666666666 2
#
# Pr[prop < mean | free, category = PHOTOGRAPHY]: 0.8498402555910542 266
# Pr[prop > mean | free, category = PHOTOGRAPHY]: 0.1501597444089457 47
#
# Pr[prop < mean | paid, category = PHOTOGRAPHY]: 0.31818181818181823 7
# Pr[prop > mean | paid, category = PHOTOGRAPHY]: 0.6818181818181818 15
#
# Pr[prop < mean | free, category = HEALTH_AND_FITNESS]: 0.7353846153846153 239
# Pr[prop > mean | free, category = HEALTH_AND_FITNESS]: 0.26461538461538464 86
#
# Pr[prop < mean | paid, category = HEALTH_AND_FITNESS]: 0.5 8
# Pr[prop > mean | paid, category = HEALTH_AND_FITNESS]: 0.5 8
#
# Pr[prop < mean | free, category = FINANCE]: 0.7507163323782235 262
# Pr[prop > mean | free, category = FINANCE]: 0.2492836676217765 87
#
# Pr[prop < mean | paid, category = FINANCE]: 0.5882352941176471 10
# Pr[prop > mean | paid, category = FINANCE]: 0.4117647058823529 7
#
# Pr[prop < mean | free, category = LIFESTYLE]: 0.8650137741046832 314
# Pr[prop > mean | free, category = LIFESTYLE]: 0.1349862258953168 49
#
# Pr[prop < mean | paid, category = LIFESTYLE]: 0.368421052631579 7
# Pr[prop > mean | paid, category = LIFESTYLE]: 0.631578947368421 12
#
# Pr[prop < mean | free, category = SPORTS]: 0.7694444444444444 277
# Pr[prop > mean | free, category = SPORTS]: 0.23055555555555557 83
#
# Pr[prop < mean | paid, category = SPORTS]: 0.16666666666666663 4
# Pr[prop > mean | paid, category = SPORTS]: 0.8333333333333334 20
#
# Pr[prop < mean | free, category = COMMUNICATION]: 0.8055555555555556 290
# Pr[prop > mean | free, category = COMMUNICATION]: 0.19444444444444445 70
#
# Pr[prop < mean | paid, category = COMMUNICATION]: 0.33333333333333337 9
# Pr[prop > mean | paid, category = COMMUNICATION]: 0.6666666666666666 18
#
# Pr[prop < mean | free, category = PERSONALIZATION]: 0.8640776699029127 267
# Pr[prop > mean | free, category = PERSONALIZATION]: 0.13592233009708737 42
#
# Pr[prop < mean | paid, category = PERSONALIZATION]: 0.32530120481927716 27
# Pr[prop > mean | paid, category = PERSONALIZATION]: 0.6746987951807228 56
#
# Pr[prop < mean | free, category = PRODUCTIVITY]: 0.8207070707070707 325
# Pr[prop > mean | free, category = PRODUCTIVITY]: 0.17929292929292928 71
#
# Pr[prop < mean | paid, category = PRODUCTIVITY]: 0.3928571428571429 11
# Pr[prop > mean | paid, category = PRODUCTIVITY]: 0.6071428571428571 17
#
# Pr[prop < mean | free, category = BUSINESS]: 0.8632286995515694 385
# Pr[prop > mean | free, category = BUSINESS]: 0.1367713004484305 61
#
# Pr[prop < mean | paid, category = BUSINESS]: 0.2142857142857143 3
# Pr[prop > mean | paid, category = BUSINESS]: 0.7857142857142857 11
#
# Pr[prop < mean | free, category = MEDICAL]: 0.8163841807909604 289
# Pr[prop > mean | free, category = MEDICAL]: 0.18361581920903955 65
#
# Pr[prop < mean | paid, category = MEDICAL]: 0.6697247706422018 73
# Pr[prop > mean | paid, category = MEDICAL]: 0.3302752293577982 36
#
# Pr[prop < mean | free, category = TOOLS]: 0.8588235294117648 657
# Pr[prop > mean | free, category = TOOLS]: 0.1411764705882353 108
#
# Pr[prop < mean | paid, category = TOOLS]: 0.42307692307692313 33
# Pr[prop > mean | paid, category = TOOLS]: 0.5769230769230769 45
#
# Pr[prop < mean | free, category = GAME]: 0.6201696512723845 658
# Pr[prop > mean | free, category = GAME]: 0.37983034872761545 403
#
# Pr[prop < mean | paid, category = GAME]: 0.22891566265060237 19
# Pr[prop > mean | paid, category = GAME]: 0.7710843373493976 64
#
# Pr[prop < mean | free, category = FAMILY]: 0.7831460674157303 1394
# Pr[prop > mean | free, category = FAMILY]: 0.21685393258426966 386
#
# Pr[prop < mean | paid, category = FAMILY]: 0.3612565445026178 69
# Pr[prop > mean | paid, category = FAMILY]: 0.6387434554973822 122

# %%
# Repeat the same process but with IP weighting
# Get the probability that the proportion of reviews is greater than the mean given the category and whether it's free or paid

mean_prop = 0.03743472632842196

# Retrieve data for plotting the graph
categories_p = []
proportions_p = []

categories_f = []
proportions_f = []

for category in ip_population:
    
    if category[3] != 0:
        categories_p.append(category[0][0])
    categories_f.append(category[0][0])
    
    sum_free = 0
    sum_paid = 0
    
    full_sum_free = 0
    full_sum_paid = 0
    for app in install_proportion:
        free_prob = category[2]/(category[2] + category[3])
        if app[3] == category[0]:
            if app[4] == 'Free':
                full_sum_free += 1
                if app[0] > mean_prop:
                    sum_free += 1
            if app[4] == 'Paid':
                full_sum_paid += 1
                if app[0] > mean_prop:
                    sum_paid += 1
    
    proportions_f.append(sum_free/category[2] * (1/free_prob))
    if category[3] != 0:
        proportions_p.append((sum_paid/category[3]) * (1/(1-free_prob)))

        
    print()
    print("free, category = {}, weighted:".format(category[0]), 
          (1/free_prob), 
          np.round((1-sum_free/category[2]) * category[1]),
          np.round((sum_free/category[2]) * category[1]))
    if sum_paid > 0:
        print("paid, category = {}, weighted:".format(category[0]), 
              (1/(1-free_prob)), 
              np.round((1-sum_paid/category[3]) * category[1]),
              np.round((sum_paid/category[3]) * category[1]))
    else:
        print("paid, category = {}, weighted:".format(category[0]), 0, 0)
# Out:
# free, category = BEAUTY, weighted: 1.0 47.0 6.0
# paid, category = BEAUTY, weighted: 0 0
#
# free, category = COMICS, weighted: 1.0 46.0 14.0
# paid, category = COMICS, weighted: 0 0
#
# free, category = PARENTING, weighted: 1.0344827586206897 54.0 6.0
# paid, category = PARENTING, weighted: 30.000000000000007 0.0 60.0
#
# free, category = EVENTS, weighted: 1.0158730158730158 51.0 13.0
# paid, category = EVENTS, weighted: 0 0
#
# free, category = ART_AND_DESIGN, weighted: 1.0483870967741935 60.0 5.0
# paid, category = ART_AND_DESIGN, weighted: 21.666666666666693 0.0 65.0
#
# free, category = WEATHER, weighted: 1.1081081081081081 66.0 16.0
# paid, category = WEATHER, weighted: 10.250000000000002 31.0 51.0
#
# free, category = AUTO_AND_VEHICLES, weighted: 1.0365853658536586 68.0 17.0
# paid, category = AUTO_AND_VEHICLES, weighted: 28.333333333333346 57.0 28.0
#
# free, category = LIBRARIES_AND_DEMO, weighted: 1.0119047619047619 80.0 5.0
# paid, category = LIBRARIES_AND_DEMO, weighted: 0 0
#
# free, category = HOUSE_AND_HOME, weighted: 1.0 78.0 10.0
# paid, category = HOUSE_AND_HOME, weighted: 0 0
#
# free, category = FOOD_AND_DRINK, weighted: 1.016 103.0 24.0
# paid, category = FOOD_AND_DRINK, weighted: 63.500000000000114 64.0 64.0
#
# free, category = MAPS_AND_NAVIGATION, weighted: 1.0378787878787878 113.0 24.0
# paid, category = MAPS_AND_NAVIGATION, weighted: 27.400000000000034 27.0 110.0
#
# free, category = ENTERTAINMENT, weighted: 1.0136054421768708 121.0 28.0
# paid, category = ENTERTAINMENT, weighted: 74.50000000000011 0.0 149.0
#
# free, category = EDUCATION, weighted: 1.0263157894736843 118.0 38.0
# paid, category = EDUCATION, weighted: 38.99999999999997 117.0 39.0
#
# free, category = VIDEO_PLAYERS, weighted: 1.023391812865497 146.0 29.0
# paid, category = VIDEO_PLAYERS, weighted: 43.7499999999999 0.0 175.0
#
# free, category = BOOKS_AND_REFERENCE, weighted: 1.1379310344827587 184.0 47.0
# paid, category = BOOKS_AND_REFERENCE, weighted: 8.25 182.0 50.0
#
# free, category = DATING, weighted: 1.0308370044052864 192.0 42.0
# paid, category = DATING, weighted: 33.42857142857142 134.0 100.0
#
# free, category = TRAVEL_AND_LOCAL, weighted: 1.048780487804878 228.0 30.0
# paid, category = TRAVEL_AND_LOCAL, weighted: 21.500000000000014 129.0 129.0
#
# free, category = SHOPPING, weighted: 1.0077519379844961 217.0 43.0
# paid, category = SHOPPING, weighted: 130.00000000000045 0.0 260.0
#
# free, category = NEWS_AND_MAGAZINES, weighted: 1.00711743772242 240.0 43.0
# paid, category = NEWS_AND_MAGAZINES, weighted: 141.499999999999 142.0 142.0
#
# free, category = SOCIAL, weighted: 1.0102739726027397 199.0 96.0
# paid, category = SOCIAL, weighted: 98.33333333333381 98.0 197.0
#
# free, category = PHOTOGRAPHY, weighted: 1.0702875399361023 285.0 50.0
# paid, category = PHOTOGRAPHY, weighted: 15.227272727272725 107.0 228.0
#
# free, category = HEALTH_AND_FITNESS, weighted: 1.0492307692307692 251.0 90.0
# paid, category = HEALTH_AND_FITNESS, weighted: 21.312500000000018 170.0 170.0
#
# free, category = FINANCE, weighted: 1.0487106017191978 275.0 91.0
# paid, category = FINANCE, weighted: 21.52941176470586 215.0 151.0
#
# free, category = LIFESTYLE, weighted: 1.0523415977961432 330.0 52.0
# paid, category = LIFESTYLE, weighted: 20.10526315789475 141.0 241.0
#
# free, category = SPORTS, weighted: 1.0666666666666667 295.0 89.0
# paid, category = SPORTS, weighted: 16.0 64.0 320.0
#
# free, category = COMMUNICATION, weighted: 1.075 312.0 75.0
# paid, category = COMMUNICATION, weighted: 14.33333333333333 129.0 258.0
#
# free, category = PERSONALIZATION, weighted: 1.2686084142394822 339.0 53.0
# paid, category = PERSONALIZATION, weighted: 4.7228915662650595 128.0 264.0
#
# free, category = PRODUCTIVITY, weighted: 1.0707070707070707 348.0 76.0
# paid, category = PRODUCTIVITY, weighted: 15.142857142857146 167.0 257.0
#
# free, category = BUSINESS, weighted: 1.031390134529148 397.0 63.0
# paid, category = BUSINESS, weighted: 32.857142857142804 99.0 361.0
#
# free, category = MEDICAL, weighted: 1.307909604519774 378.0 85.0
# paid, category = MEDICAL, weighted: 4.247706422018347 310.0 153.0
#
# free, category = TOOLS, weighted: 1.1019607843137256 724.0 119.0
# paid, category = TOOLS, weighted: 10.807692307692303 357.0 486.0
#
# free, category = GAME, weighted: 1.0782280867106504 709.0 435.0
# paid, category = GAME, weighted: 13.783132530120472 262.0 882.0
#
# free, category = FAMILY, weighted: 1.107303370786517 1544.0 428.0
# paid, category = FAMILY, weighted: 10.319371727748686 712.0 1260.0

# %%
plt.bar(categories_f, proportions_f)
# Out:
# <BarContainer object of 33 artists>

# %%
plt.bar(categories_p, proportions_p)
# Out:
# <BarContainer object of 30 artists>

# %% [markdown]
# # Backdoor Path Correction
#
# In order to account for backdoor paths in our code, we must adjust probabilities in accordance to the category given, to adjust for confounding.
